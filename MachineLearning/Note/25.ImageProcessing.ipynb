# %% [markdown]
# #### PTL (Pillow)를 이용한 Image처리

# %%
# !pip install Pillow

# %%
from PIL import Image

# %%
# 이미지 불러오기
cat = Image.open('../Data/cat.png')

# %%
cat
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=169x158>

# %%
# Image Layer 확인
cat.getbands()
# Out:
# ('R', 'G', 'B')

# %%
cat.mode
# Out:
# 'RGB'

# %%
cat.size
# Out:
# (169, 158)

# %%
cat.filename
# Out:
# '../Data/cat.png'

# %%
cat.format
# Out:
# 'PNG'

# %%
# Image Resize
cat_resize = cat.resize((169, 169))
cat_resize
# Out:
# <PIL.Image.Image image mode=RGB size=169x169>

# %%
# Image Rotate
cat_rotate = cat.rotate(180)
cat_rotate
# Out:
# <PIL.Image.Image image mode=RGB size=169x158>

# %%
# Numpy Array로 변경
import numpy as np
cat_array = np.array(cat)
cat_array
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], shape=(158, 169, 3), dtype=uint8)

# %%
# Color Transformation
cat.convert('L')
# L = gray color
# Out:
# <PIL.Image.Image image mode=L size=169x158>

# %%
cat.convert('RGBA')
# Out:
# <PIL.Image.Image image mode=RGBA size=169x158>
