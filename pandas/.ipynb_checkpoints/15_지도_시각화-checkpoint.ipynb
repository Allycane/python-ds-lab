# %% [markdown]
# # 지도 시각화

# %%
# !pip install folium

# %% [markdown]
# ### 기본 지도 그리기

# %%
import folium

m = folium.Map(
    location=[37.566826, 126.9786567],
    zoom_start=11
)

m.save('data/map_basic.html')
print('지도 저장 완료: data/map_basic.html')
m
# Out:
# 지도 저장 완료: data/map_basic.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e966495a757059691f285838c603445 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e966495a757059691f285838c603445&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e966495a757059691f285838c603445 = L.map(
#                 &quot;map_0e966495a757059691f285838c603445&quot;,
#                 {
#                     center: [37.566826, 126.9786567],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37840c3e91164c931c3c4accbf47b151 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_37840c3e91164c931c3c4accbf47b151.addTo(map_0e966495a757059691f285838c603445);
#
#
#             tile_layer_37840c3e91164c931c3c4accbf47b151.addTo(map_0e966495a757059691f285838c603445);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# [예제 2] 마커 + 팝업 + 툴팁

locations = [
    {'name': '경복궁', 'lat': 37.5796, 'lon': 126.9770, 'desc': '조선의 법궁'},
    {'name': '남산타워', 'lat': 37.5512, 'lon': 126.9882, 'desc': 'N서울타워'},
    {'name': '인사동', 'lat': 37.5741, 'lon': 126.9862, 'desc': '전통문화거리'},
]

m2 = folium.Map(location=[37.566, 126.977], zoom_start=13)

for loc in locations:
    folium.Marker(
        location=[loc['lat'], loc['lon']],
        popup=folium.Popup(f"<b>{loc['name']}</b><br>{loc['desc']}", max_width=200),
        tooltip=loc['name'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m2)

m2.save('data/map_markers.html')
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_466f634d524ec300b73692faa813f95b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_466f634d524ec300b73692faa813f95b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_466f634d524ec300b73692faa813f95b = L.map(
#                 &quot;map_466f634d524ec300b73692faa813f95b&quot;,
#                 {
#                     center: [37.566, 126.977],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1c54eb1615af03a1ea2d694ddb2bb2f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c1c54eb1615af03a1ea2d694ddb2bb2f.addTo(map_466f634d524ec300b73692faa813f95b);
#
#
#             var marker_265f8984d8e2ce15d177177b8f18f118 = L.marker(
#                 [37.5796, 126.977],
#                 {
# }
#             ).addTo(map_466f634d524ec300b73692faa813f95b);
#
#
#             var icon_67132a83274902e2d1d09ef9bb701bbd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_82c81011c767d38875b377bdcad219c6 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_5ab929b542ab422c1669fb2f66675a10 = $(`&lt;div id=&quot;html_5ab929b542ab422c1669fb2f66675a10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;경복궁&lt;/b&gt;&lt;br&gt;조선의 법궁&lt;/div&gt;`)[0];
#                 popup_82c81011c767d38875b377bdcad219c6.setContent(html_5ab929b542ab422c1669fb2f66675a10);
#
#
#
#         marker_265f8984d8e2ce15d177177b8f18f118.bindPopup(popup_82c81011c767d38875b377bdcad219c6)
#         ;
#
#
#
#
#             marker_265f8984d8e2ce15d177177b8f18f118.bindTooltip(
#                 `&lt;div&gt;
#                      경복궁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_265f8984d8e2ce15d177177b8f18f118.setIcon(icon_67132a83274902e2d1d09ef9bb701bbd);
#
#
#             var marker_38bca0613db75eec110a627f3cbb5ee9 = L.marker(
#                 [37.5512, 126.9882],
#                 {
# }
#             ).addTo(map_466f634d524ec300b73692faa813f95b);
#
#
#             var icon_adbff76e7049fbfd6790f19230e133cf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0e405ccefd9c4e0975d83200b864d7c8 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_8bfb3e7ed1736682719b98673b2c3df5 = $(`&lt;div id=&quot;html_8bfb3e7ed1736682719b98673b2c3df5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;남산타워&lt;/b&gt;&lt;br&gt;N서울타워&lt;/div&gt;`)[0];
#                 popup_0e405ccefd9c4e0975d83200b864d7c8.setContent(html_8bfb3e7ed1736682719b98673b2c3df5);
#
#
#
#         marker_38bca0613db75eec110a627f3cbb5ee9.bindPopup(popup_0e405ccefd9c4e0975d83200b864d7c8)
#         ;
#
#
#
#
#             marker_38bca0613db75eec110a627f3cbb5ee9.bindTooltip(
#                 `&lt;div&gt;
#                      남산타워
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_38bca0613db75eec110a627f3cbb5ee9.setIcon(icon_adbff76e7049fbfd6790f19230e133cf);
#
#
#             var marker_665ea4ac4499c5b32864f8273219288d = L.marker(
#                 [37.5741, 126.9862],
#                 {
# }
#             ).addTo(map_466f634d524ec300b73692faa813f95b);
#
#
#             var icon_4d4a32414c1b21f3f5d390f639a86390 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_94793f2c923d759d71e04d19ebe24853 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_d1778d1f1d46cc66d05344bf12b6f7e1 = $(`&lt;div id=&quot;html_d1778d1f1d46cc66d05344bf12b6f7e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&l

# %%
import pandas as pd

data = [
    ('강남구', 37.5172, 127.0473, 564000),
    ('서초구', 37.4837, 127.0324, 444000),
    ('종로구', 37.5730, 126.9794, 153000),
    ('송파구', 37.5145, 127.1058, 671000),
    ('강서구', 37.5509, 126.8495, 588000),
    ('노원구', 37.6541, 127.0568, 514000),
]
df = pd.DataFrame(data, columns=['구', '위도', '경도', '인구'])

m3 = folium.Map(location=[37.566, 126.978], zoom_start=11)

for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row['위도'], row['경도']],
        radius=row['인구'] / 20000,
        color='crimson',
        fill=True,
        fill_color='crimson',
        fill_opacity=0.5,
        tooltip=f"{row['구']}: {row['인구']:,}명"
    ).add_to(m3)

m3.save('data/map_circle.html')
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f940174af95af8b05c1dbb102817f15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f940174af95af8b05c1dbb102817f15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f940174af95af8b05c1dbb102817f15 = L.map(
#                 &quot;map_8f940174af95af8b05c1dbb102817f15&quot;,
#                 {
#                     center: [37.566, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0cbdd1008e2dc76b764bda266df6f41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0cbdd1008e2dc76b764bda266df6f41.addTo(map_8f940174af95af8b05c1dbb102817f15);
#
#
#             var circle_marker_1b929edbf6619f5bcef7bb2132e459df = L.circleMarker(
#                 [37.5172, 127.0473],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 28.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8f940174af95af8b05c1dbb102817f15);
#
#
#             circle_marker_1b929edbf6619f5bcef7bb2132e459df.bindTooltip(
#                 `&lt;div&gt;
#                      강남구: 564,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_abe6a8e7b4c70f76415f25ade589a5e3 = L.circleMarker(
#                 [37.4837, 127.0324],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8f940174af95af8b05c1dbb102817f15);
#
#
#             circle_marker_abe6a8e7b4c70f76415f25ade589a5e3.bindTooltip(
#                 `&lt;div&gt;
#                      서초구: 444,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_79daf124f37a86c4a6de6afa21d5483e = L.circleMarker(
#                 [37.573, 126.9794],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.65, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8f940174af95af8b05c1dbb102817f15);
#
#
#             circle_marker_79daf124f37a86c4a6de6afa21d5483e.bindTooltip(
#                 `&lt;div&gt;
#                      종로구: 153,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_10a267ca2793450889a574c01bdedfa2 = L.circleMarker(
#                 [37.5145, 127.1058],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 33.55, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8f940174af95af8b05c1dbb102817f15);
#
#
#             circle_marker_10a267ca2793450889a574c01bdedfa2.bindTooltip(
#                 `&lt;div&gt;
#                      송파구: 671,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_47f991c82de7a59e3024e29c98f8e38c = L.circleMarker(
#                 [37.5509, 126.8495],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArr

# %% [markdown]
# ### 지하철 2호선 혼잡도 히트맵

# %%
import folium
from folium.plugins import HeatMap

line2_stations = [
    ('강남', 37.4979, 127.0276, 200000),
    ('홍대입구', 37.5572, 126.9249, 190000),
    ('신촌', 37.5553, 126.9364, 160000),
    ('신림', 37.4846, 126.9290, 175000),
    ('구로디지털단지', 37.4854, 126.9012, 140000),
    ('잠실', 37.5133, 127.1001, 210000),
    ('왕십리', 37.5613, 127.0375, 130000),
    ('성수', 37.5445, 127.0556, 120000),
    ('서울대입구', 37.4812, 126.9528, 145000),
    ('사당', 37.4763, 126.9817, 180000),
]

m_heat = folium.Map(location=[37.530, 126.990], zoom_start=12)

# 히트맵 데이터: [위도, 경도, 가중치]
heat_data = [[s[1], s[2], s[3] / 210000] for s in line2_stations]

HeatMap(heat_data, radius=30, blur=20, max_zoom=13).add_to(m_heat)

# 역명 마커 추가
for name, lat, lon, cnt in line2_stations:
    folium.CircleMarker(
        location=[lat, lon], radius=6,
        color='darkblue', fill=True, fill_color='white',
        tooltip=f'{name}: {cnt:,}명'
    ).add_to(m_heat)

m_heat.save('data/map_subway_heat.html')
m_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0440168c67d9cacbbe1a5a4a55a321e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0440168c67d9cacbbe1a5a4a55a321e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0440168c67d9cacbbe1a5a4a55a321e1 = L.map(
#                 &quot;map_0440168c67d9cacbbe1a5a4a55a321e1&quot;,
#                 {
#                     center: [37.53, 126.99],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c47773e90745d400166d0a05879e7fcf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c47773e90745d400166d0a05879e7fcf.addTo(map_0440168c67d9cacbbe1a5a4a55a321e1);
#
#
#             var heat_map_c4e14ff97b12af81eed81af0bebba5c6 = L.heatLayer(
#                 [[37.4979, 127.0276, 0.9523809523809523], [37.5572, 126.9249, 0.9047619047619048], [37.5553, 126.9364, 0.7619047619047619], [37.4846, 126.929, 0.8333333333333334], [37.4854, 126.9012, 0.6666666666666666], [37.5133, 127.1001, 1.0], [37.5613, 127.0375, 0.6190476190476191], [37.5445, 127.0556, 0.5714285714285714], [37.4812, 126.9528, 0.6904761904761905], [37.4763, 126.9817, 0.8571428571428571]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 13,
#   &quot;radius&quot;: 30,
#   &quot;blur&quot;: 20,
# }
#             );
#
#
#             heat_map_c4e14ff97b12af81eed81af0bebba5c6.addTo(map_0440168c67d9cacbbe1a5a4a55a321e1);
#
#
#             var circle_marker_31ce59c0062f2b323b1f5a5ff03d5b4b = L.circleMarker(
#                 [37.4979, 127.0276],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0440168c67d9cacbbe1a5a4a55a321e1);
#
#
#             circle_marker_31ce59c0062f2b323b1f5a5ff03d5b4b.bindTooltip(
#                 `&lt;div&gt;
#                      강남: 200,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6e35eb0e546fece40ecb4e9b830fa783 = L.circleMarker(
#                 [37.5572, 126.9249],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0440168c67d9cacbbe1a5a4a55a321e1);
#
#
#             circle_marker_6e35eb0e546fece40ecb4e9b830fa783.bindTooltip(
#                 `&lt;div&gt;
#                      홍대입구: 190,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_145ebfbb440abc666e73b3347f8bef55 = L.circleMarker(
#                 [37.5553, 126.9364],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0440168c67d9cacbbe1a5a4a55a321e1);
#
#
#             circle_marker_145ebfbb440abc666e73b3347f8bef55.bindTooltip(
#                 `&lt;div&gt;
#                      신촌: 160,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_18ca08ec8610ff64f5e291653e9d230a = L.circleMarker(
#                 [37.4846, 126.929],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dash

# %% [markdown]
# ### 따릉이 대여소 위치

# %%
df = pd.read_excel('data/공공자전거 대여소 정보(25.12월 기준).xlsx', header=None)
# df.head(10)
df_bike = df.iloc[5:,[1, 2, 4, 5, 8]] # 앞은 행, 뒤는 컬럼 / 1: 대여소명, 2: 자치구, 4: 위도, 5: 경도
df_bike.head()
# Out:
#              1    2          4           5   8
# 5   망원역 1번출구 앞  마포구  37.555649  126.910629  15
# 6   망원역 2번출구 앞  마포구  37.554951  126.910835  14
# 7   합정역 1번출구 앞  마포구  37.550629  126.914986  13
# 8   합정역 5번출구 앞  마포구  37.550007  126.914825   5
# 9   합정역 7번출구 앞  마포구  37.548645  126.912827  12

# %%
# 컬럼명 수정
df_bike.columns = ['대여소명', '자치구', '위도', '경도', '거치대수']

# %%
# 결측치 확인
df_bike.isna().sum()
# Out:
# 대여소명       0
# 자치구        0
# 위도         0
# 경도         0
# 거치대수    1059
# dtype: int64

# %%
df_bike.dtypes
# Out:
# 대여소명    object
# 자치구     object
# 위도      object
# 경도      object
# dtype: object

# %%
# 자치구별 거치대수가 가장 많은 대여소 필터
st = df_bike.loc[df_bike.groupby('자치구')['거치대수'].sum()]
st['위도'] = st['위도'].astype(float)
st['경도'] = st['경도'].astype(float)
st.info()
st
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 907 to 517
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소명    25 non-null     object
#  1   자치구     25 non-null     object
#  2   위도      25 non-null     float64
#  3   경도      25 non-null     float64
#  4   거치대수    9 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB
#                       대여소명   자치구         위도          경도 거치대수
# 907               석관초등학교 앞   성북구  37.610523  127.059799  NaN
# 892                   성북구청   성북구  37.589329  127.016434  NaN
# 240            종묘공영주차장 건너편   종로구  37.570480  126.996635  NaN
# 2129   휴플러스 수락한신아파트 101동 앞   노원구  37.674366  127.059471    6
# 354              한양대후문역 부근   성동구  37.560356  127.041397  NaN
# 721               고덕역 5번출구   강동구  37.554863  127.153725   22
# 608                 신도고등학교   은평구  37.630016  126.919029  NaN
# 400              휘경2동 주민센터  동대문구  37.589912  127.068680   10
# 1005             동부시장 북문 앞   중랑구  37.593868  127.076523    9
# 468                양서중학교 옆   양천구  37.533047  126.829956   20
# 779              강서면허시험장 앞   강서구  37.549694  126.819664  NaN
# 406                   제기2교  동대문구  37.587746  127.037384  NaN
# 1291           고척LIGA아파트 앞   구로구  37.506050  126.860786  NaN
# 751           염창동 한마음아파트 앞   강서구  37.554253  126.867561  NaN
# 810            엠펠리체 호텔 건너편   강서구  37.560242  126.835808  NaN
# 759           화곡본동시장 버스정류장   강서구  37.542751  126.842621  NaN
# 365              대림아크로리버 앞   광진구  37.536579  127.092972  NaN
# 1661            잠실새내역 1번출구   송파구  37.511295  127.086739   21
# 863              문정동 글샘 공원   송파구  37.478809  127.120003   10
# 1767            홍대입구역 3번출구   마포구  37.558296  126.925385   15
# 753              가양레포츠센터 앞   강서구  37.559479  126.864380  NaN
# 505            오목로 무중력지대 앞   양천구  37.524742  126.877663  NaN
# 909                 성북3교 위   성북구  37.591251  127.014008  NaN
# 803                롯데중앙연구소   강서구  37.571381  126.828339  NaN
# 517         세종그랑시아 앞(102동)   양천구  37.538376  126.863831   10

# %%
# 데이터를 이용하여 지도 형성
m_bike = folium.Map(location=[37.530, 126.990], zoom_start=12)

# %%
# 마커 생성
for idx, row in st.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=['대여소명'],
        tooltip=row['대여소명']
    ).add_to(m_bike)

m_bike.save('data/map_bike.html')
m_bike
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80026fc0294f01a4a0f26f469be002fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80026fc0294f01a4a0f26f469be002fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80026fc0294f01a4a0f26f469be002fa = L.map(
#                 &quot;map_80026fc0294f01a4a0f26f469be002fa&quot;,
#                 {
#                     center: [37.53, 126.99],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_674e688f2f8017ef15b5744ad09362c6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_674e688f2f8017ef15b5744ad09362c6.addTo(map_80026fc0294f01a4a0f26f469be002fa);
#
#
#             var marker_7eff0f43d00993443e4a5f4c54e0742d = L.marker(
#                 [37.5556488, 126.91062927],
#                 {
# }
#             ).addTo(map_80026fc0294f01a4a0f26f469be002fa);
#
#
#         var popup_b4293c535e5af2295b52918014bdc44d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ad40bdf9a2fd25ee3353fee1476a54f = $(`&lt;div id=&quot;html_2ad40bdf9a2fd25ee3353fee1476a54f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;대여소명&#x27;]&lt;/div&gt;`)[0];
#                 popup_b4293c535e5af2295b52918014bdc44d.setContent(html_2ad40bdf9a2fd25ee3353fee1476a54f);
#
#
#
#         marker_7eff0f43d00993443e4a5f4c54e0742d.bindPopup(popup_b4293c535e5af2295b52918014bdc44d)
#         ;
#
#
#
#
#             marker_7eff0f43d00993443e4a5f4c54e0742d.bindTooltip(
#                 `&lt;div&gt;
#                       망원역 1번출구 앞
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_6aa9915997d730adceb3bdf16e02cc38 = L.marker(
#                 [37.55495071, 126.91083527],
#                 {
# }
#             ).addTo(map_80026fc0294f01a4a0f26f469be002fa);
#
#
#         var popup_341504a59205b66e94edfbc5f74a505b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c1b786d9dd2f7d550dfb8eef05e06c7 = $(`&lt;div id=&quot;html_9c1b786d9dd2f7d550dfb8eef05e06c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;대여소명&#x27;]&lt;/div&gt;`)[0];
#                 popup_341504a59205b66e94edfbc5f74a505b.setContent(html_9c1b786d9dd2f7d550dfb8eef05e06c7);
#
#
#
#         marker_6aa9915997d730adceb3bdf16e02cc38.bindPopup(popup_341504a59205b66e94edfbc5f74a505b)
#         ;
#
#
#
#
#             marker_6aa9915997d730adceb3bdf16e02cc38.bindTooltip(
#                 `&lt;div&gt;
#                       망원역 2번출구 앞
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ccf26ddb0de11000d341ae73b13e9690 = L.marker(
#                 [37.55062866, 126.91498566],
#                 {
# }
#             ).addTo(map_80026fc0294f01a4a0f26f469be002fa);
#
#
#         var popup_3c71453491e46265c419e1e17ca5709e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0f108e674ffd9c491fd5ace3b09a5c5 = $(`&lt;div id=&quot;html_d0f108e674ffd9c491fd5ace3b09a5c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;대여소명&#x27;]&lt;/div&gt;`)[0];
#                 popup_3c71453491e46265c419e1e17ca5709e.setContent(html_d0f108e674ffd9c491fd5ace3b09a5c5);
#
#
#
#         marker_ccf26ddb0de11000d341ae73b13e9690.bindPopup(popup_3c71453491e46265c419e1e17ca5709e)
#         ;
#
#
#
#
#             marker_ccf26ddb0de11000d341ae73b13e9690.bindTooltip(
#                 `&lt;div&gt;
#                       합정역 1번출구 앞
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_fde693e15540d95f2eea0c5d79b97ac0 = L.marker(
#                 [37.55000687, 126.91482544],
#                 {
# }
#             ).addTo(map_80026fc0294f01a4a0f26f469be002fa);
#
#
#         var popup_cbe8c7632184db14d870e372190a9663 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85fff8d2a869ce9a636698ee6e25911a = $(`&lt;div id=&quot;html_85fff8d2a869ce9a636698ee6e25911a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;대여소명&#x27;]&lt;/div&gt;`)[0];
#                 popup_cbe8c7632184db14d870e372190a9663.setContent(html_85fff8d2a869ce9a636698ee6e25911a);
#
#
#
#         marker_fde693e15540d95f2eea0c5d79b97ac0.bindPopup(popup_cbe8c76321
