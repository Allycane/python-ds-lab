# %% [markdown]
# Q1.
# 넘파이 모듈을 np라는 약칭으로 임포트하는 코드를 작성하세요.

# %%
import numpy as np

# %% [markdown]
# Q2.
# 넘파이의 가장 기본적인 데이터 타입인 다차원 배열 객체의 이름은 무엇입니까? - ndarray()

# %% [markdown]
# Q3.
# 리스트 [1, 2, 3]을 인자로 받아 1차원 ndarray를 생성하는 코드를 작성하세요.

# %%
np.array([1, 2, 3])
# Out:
# array([1, 2, 3])

# %% [markdown]
# Q4.
# 생성된 ndarray의 크기(행과 열의 수)를 튜플 형태로 확인하는 속성은 무엇입니까?
